# %% [markdown]
# ## Communicate Insights
# The report provides you with insights from these research questions.
# > <li><a href="#intro">Description of the dataset</a></li>
# > <li><a href="#rq1">How many vessels were used before and since invasion?</a></li>
# > <li><a href="#rq3">What commodity does each of these ship types convey as well as the number of times they were conveyed?</a></li>
# > <li><a href="#rq4">The number of times each of these commodities were shipped out of Russia</a></li>
#
# > <li><a href="#rq5">What is the aggregate tonnes shipped out?</a></li>
# > <li><a href="#rq6">What is the aggregate tonnes of commodities shipped out?</a></li>
# > <li><a href="#rq7">What is the aggregate cost based on ship type?</a></li>
# > <li><a href="#rq8">What is the aggregate cost of commodities shipped out?</a></li>
#
# > <li><a href="#rq9">How many tonnes of products leave each port?</a></li>
# > <li><a href="#rq10">How many tonnes of commodities leave each port? A more detailed outlook</a></li>
# > <li><a href="#rq11">How many tonnes of products arrived the three ports?</a></li>
# > <li><a href="#rq12">How many tonnes of commodities arrived the three ports? A more detailed outlook</a></li>
#
# > <li><a href="#rq13">Who are the managers of the vessels?</a></li>
# > <li><a href="#rq14">Which country do the ship managers come from?</a></li>
# > <li><a href="#rq15">Who are the owners of the vessels?</a></li>
# > <li><a href="#rq16">Which country do the ship owners come from?</a></li>
# > <li><a href="#rq17">Insurance companies before and since invasion</a></li>
# > <li><a href="#rq2">Where are those ships insured?</a></li>
# > <li><a href="#rq18">Which countries are the insurance companies located?</a></li>

# %% [markdown]
# <a id='intro'></a>
# ### Dataset description
# > The dataset for the shipment is between `13th January, 2021` and `23rd May, 2023`.
# >
# > The whole dataset contains 12,127 observation and 88 variables.
# >
# > After filtering the entire dataset, we are left with 35 records associated with Nigeria.

# %% [markdown]
# <a id='rq1'></a>
# ### How many vessels were used before and since invasion?
# ![Vessels_Usage.png](attachment:Vessels_Usage.png)
#
# ### Narrative
# > There are *`28`* unique/distinct vessels available in the dataset.
# >
# > **Scenario 1** - Before invasion *(7 vessels were used)*
#   > + *LORELEI* and *HAFNIA BEIJING* vessels were used `six and two times` respectively.
#   >
#   > + *ADVANTAGE POINT, ANCE, BONDI, ARCTIC CHAR* and *NORTHERN LIGHT* were used `once for each one`.
#   >
# >
# > **Scenario 2** - Since invasion *(21 vessels were used)*
#   > + *DUMBLEDORE* was used `twice`.
#   >
#   > + *LOUIE, NAVE DORADO, ANDROMEDA, FALCON NOSTOS, DYLAN, CAPE GAVI, JANE, ST NICHOLAS, LUCKY LADY, MINERVA PACIFICA, LUCKY SAILOR, ALPINE LIGHT, CLEAN NIRVANA, CLEAROCEAN MIRACLE, MARLIN AMMOLITE, TATIANA P, AGIOS NIKOLAOS IV, NS STREAM, ESENTEPE* and *SCF ANGARA* were used `once for each one`.

# %% [markdown]
# <a id='rq3'></a>
# ### What commodity does each of these ship types convey as well as the number of times they were conveyed?
# ![Commodities_Conveyed_by_shipTypes.png](attachment:Commodities_Conveyed_by_shipTypes.png)
#
# ### Narrative
# > + *`CRUDE OIL TANKER`* exported Crude oil `once`.
# >
# > + *`Cargo`* exported Coal `once`.
# >
# > + *`OIL/CHEMICAL TANKER`* exported Oil or chemicals `ten times`.
# >
# > + *`Tanker`* exported Oil or chemicals `seven times`.
# >
# > + *`Tanker - Hazard A (Major)`* exported Oil or chemicals `two times`.
# >
# > + *`Tanker - Hazard C (Minor)`* exported Oil or chemicals `once`.
# >
# > + *`Tanker - Hazard D (Recognizable)`* exported Oil or chemicals `once`.
# >
# > + *`OIL PRODUCTS TANKER`* exported Oil products `twelve times`.

# %% [markdown]
# <a id='rq4'></a>
# ### The number of times each of these commodities were shipped out of Russia
# ![No_of_Times_CommoditiesShippedOut-2.png](attachment:No_of_Times_CommoditiesShippedOut-2.png)
#
# ### Narrative
# > **Scenario 1** - Before invasion
#   > + *`OIL/CHEMICAL TANKER`* exported Oil or chemicals `two times`.
#   >
#   > + *`Tanker`* exported Oil or chemicals `three times`.
#   >
#   > + *`Tanker - Hazard D (Recognizable)`* exported Oil or chemicals `once`.
#   >
#   > + *`OIL PRODUCTS TANKER`* exported Oil products `seven times`.
# >
# > **Scenario 2** - Since invasion
#   > + *`CRUDE OIL TANKER`* exported Crude oil `once`.
#   >
#   > + *`Cargo`* exported Coal `once`.
#   >
#   > + *`OIL/CHEMICAL TANKER`* exported Oil or chemicals `eight times`.
#   >
#   > + *`Tanker`* exported Oil or chemicals `four times`.
#    >
#   > + *`Tanker - Hazard A (Major)`* exported Oil or chemicals `two times`.
#   >
#   > + *`Tanker - Hazard C (Minor)`* exported Oil or chemicals `once`.
#   >
#   > + *`OIL PRODUCTS TANKER`* exported Oil products `five times`.

# %% [markdown]
# <a id='rq5'></a>
# ### What is the aggregate tonnes shipped out?
# ![Aggregate_Tonnes_ShippedOut.png](attachment:Aggregate_Tonnes_ShippedOut.png)
#
# ### Narrative
# > **Scenario 1** - Before invasion
#   > + *`OIL/CHEMICAL TANKER`* transported 150.0k _tonnes_ of product.
#   >
#   > + *`Tanker`* transported 118.7k _tonnes_ of product.
#   >
#   > + *`Tanker - Hazard D (Recognizable)`* transported 37.0k _tonnes_ of product.
#   >
#   > + *`OIL PRODUCTS TANKER`* transported 516.5k _tonnes_ of product.
# >
# > **Scenario 2** - Since invasion
#   > + *`CRUDE OIL TANKER`* transported 52.0k _tonnes_ of product.
#   >
#   > + *`Cargo`* transported 44.8k _tonnes_ of Coal.
#   >
#   > + *`OIL/CHEMICAL TANKER`* transported 374.7k _tonnes_ of product.
#   >
#   > + *`Tanker`* transported 166.9k _tonnes_ of product.
#    >
#   > + *`Tanker - Hazard A (Major)`* transported 75.2k _tonnes_ of product.
#   >
#   > + *`Tanker - Hazard C (Minor)`* transported 51.4k _tonnes_ of product.
#   >
#   > + *`OIL PRODUCTS TANKER`* transported 248.3k _tonnes_ of product.

# %% [markdown]
# <a id='rq6'></a>
# ### What is the aggregate tonnes of commodities shipped out?
# ![Aggregate_Tonnes_of_Commodities_ShippedOut.png](attachment:Aggregate_Tonnes_of_Commodities_ShippedOut.png)
#
# ### Narrative
# > **Scenario 1** - Before invasion
#   > + *`OIL/CHEMICAL TANKER`* transported 150.0k _tonnes_ of Oil or chemicals.
#   >
#   > + *`Tanker`* transported 118.7k _tonnes_ of Oil or chemicals.
#   >
#   > + *`Tanker - Hazard D (Recognizable)`* transported 37.0k _tonnes_ of Oil or chemicals.
#   >
#   > + *`OIL PRODUCTS TANKER`* transported 516.5k _tonnes_ of Oil products.
# >
# > **Scenario 2** - Since invasion
#   > + *`CRUDE OIL TANKER`* transported 52.0k _tonnes_ of Crude oil.
#   >
#   > + *`Cargo`* transported 44.8k _tonnes_ of Coal.
#   >
#   > + *`OIL/CHEMICAL TANKER`* transported 374.7k _tonnes_ of Oil or chemicals.
#   >
#   > + *`Tanker`* transported 166.9k _tonnes_ of Oil or chemicals.
#    >
#   > + *`Tanker - Hazard A (Major)`* transported 75.2k _tonnes_ of Oil or chemicals.
#   >
#   > + *`Tanker - Hazard C (Minor)`* transported 51.4k _tonnes_ of Oil or chemicals.
#   >
#   > + *`OIL PRODUCTS TANKER`* transported 248.3k _tonnes_ of Oil products.

# %% [markdown]
# <a id='rq7'></a>
# ### What is the aggregate cost based on ship type?
# ![Aggregate_Cost_based_on_ShipTypes.png](attachment:Aggregate_Cost_based_on_ShipTypes.png)
#
# ### Narrative
# > **Scenario 1** - Before invasion
#   > + US\$39.0 _million_ worth of product was shipped using *`OIL/CHEMICAL TANKER`*.
#   >
#   > + US\$66.1 _million_ worth of product was shipped using *`Tanker`*.
#   >
#   > + US\$27.1 _million_ worth of product was shipped using *`Tanker - Hazard D (Recognizable)`*.
#   >
#   > + US\$83.2 _million_ worth of product was shipped using *`OIL PRODUCTS TANKER`*.
# >
# > **Scenario 2** - Since invasion
#   > + US\$18.7 _million_ worth of product was shipped using *`CRUDE OIL TANKER`*.
#   >
#   > + US\$10.1 _million_ worth of product was shipped using *`Cargo`*.
#   >
#   > + US\$227.2 _million_ worth of product was shipped using *`OIL/CHEMICAL TANKER`*.
#   >
#   > + US\$103.3 _million_ worth of product was shipped using *`Tanker`*.
#    >
#   > + US\$52.9 _million_ worth of product was shipped using *`Tanker - Hazard A (Major)`*.
#   >
#   > + US\$32.1 _million_ worth of product was shipped using *`Tanker - Hazard C (Minor)`*.
#   >
#   > + US\$152.4 _million_ worth of product was shipped using *`OIL PRODUCTS TANKER`*.

# %% [markdown]
# <a id='rq8'></a>
# ### What is the aggregate cost of commodities shipped out?
# ![Aggregate_Cost_of_Commodities_ShippedOut_Detailed-2.png](attachment:Aggregate_Cost_of_Commodities_ShippedOut_Detailed-2.png)
#
# ### Narrative
# > **Scenario 1** - Before invasion
#   > + Oil or chemicals worth US\$39.0 _million_ was shipped using *`OIL/CHEMICAL TANKER`*.
#   >
#   > + Oil or chemicals worth US\$66.1 _million_ was shipped using *`Tanker`*.
#   >
#   > + Oil or chemicals worth US\$27.1 _million_ was shipped using *`Tanker - Hazard D (Recognizable)`*.
#   >
#   > + Oil products worth US\$83.2 _million_ was shipped using *`OIL PRODUCTS TANKER`*.
# >
# > **Scenario 2** - Since invasion
#   > + Crude oil worth US\$18.7 _million_ was shipped using *`CRUDE OIL TANKER`*.
#   >
#   > + Coal worth US\$10.1 _million_ was shipped using *`Cargo`*.
#   >
#   > + Oil or chemicals worth US\$227.2 _million_ was shipped using *`OIL/CHEMICAL TANKER`*.
#   >
#   > + Oil or chemicals worth US\$103.3 _million_ was shipped using *`Tanker`*.
#    >
#   > + Oil or chemicals worth US\$52.9 _million_ was shipped using *`Tanker - Hazard A (Major)`*.
#   >
#   > + Oil or chemicals worth US\$32.1 _million_ was shipped using *`Tanker - Hazard C (Minor)`*.
#   >
#   > + Oil products worth US\$152.4 _million_ was shipped using *`OIL PRODUCTS TANKER`*.

# %% [markdown]
# <a id='rq9'></a>
# ### How many tonnes of products leave each port?
# ![Tonnes_of_Commodities_left_the_Port.png](attachment:Tonnes_of_Commodities_left_the_Port.png)
#
# ### Narrative
# > There are *`10`* unique/distinct departure_port_name associated with Nigeria.
# >
# > **Scenario 1** - Before invasion
#   > + 15.2k _tonnes_ of Oil or chemicals was exported from *`Baltiysk`* port.
#   >
#   > + 75.0k _tonnes_ of Oil products was exported from *`Primorsk (Koivisto)`* port.
#   >
#   > + 695.1k _tonnes_ of products was exported from *`Ust'-Lugak`* port.
#   >
#   > + 37.0k _tonnes_ of Oil or chemicals was exported from *`Vysotsk`* port.
# >
# > **Scenario 2** - Since invasion
#   > + 45.8k _tonnes_ of Oil products was exported from *`Murmansk`* port.
#   >
#   > + 75.0k _tonnes_ of products was exported from *`Saint Petersburg (ex Leningrad)`* port.
#   >
#   > + 44.8k _tonnes_ of products was exported from *`TAMAN ANCH`* port.
#   >
#   > + 40.3k _tonnes_ of products was exported from *`TUAPSE ANCH`* port.
#   >
#   > + 37.6k _tonnes_ of products was exported from *`Taman'`* port.
#   >
#   > + 37.3k _tonnes_ of products was exported from *`Tuapse`* port.
#   >
#   > + 605.5k _tonnes_ of products was exported from *`Ust'-Lugak`* port.
#   >
#   > + 126.9k _tonnes_ of products was exported from *`Vysotsk`* port.

# %% [markdown]
# <a id='rq10'></a>
# ### How many tonnes of commodities leave each port? A more detailed outlook
# ![Tonnes_of_Commodities_left_the_port_MoreDetailed.png](attachment:Tonnes_of_Commodities_left_the_port_MoreDetailed.png)
#
# ### Narrative
# > There are *`10`* unique/distinct departure_port_name associated with Nigeria.
# >
# > **Scenario 1** - Before invasion
#   > + 15.2k _tonnes_ of Oil or chemicals was exported from *`Baltiysk`* port.
#   >
#   > + 75.0k _tonnes_ of Oil products was exported from *`Primorsk (Koivisto)`* port.
#   >
#   > + 253.5k _tonnes_ of Oil or chemicals and 441.5k tonnes of Oil products were exported from *`Ust'-Lugak`* port.
#   >
#   > + 37.0k _tonnes_ of Oil or chemicals was exported from *`Vysotsk`* port.
# >
# > **Scenario 2** - Since invasion
#   > + 45.8k _tonnes_ of Oil products was exported from *`Murmansk`* port.
#   >
#   > + 75.0k _tonnes_ of Oil or chemicals was exported from *`Saint Petersburg (ex Leningrad)`* port.
#   >
#   > + 44.8k _tonnes_ of Coal was exported from *`TAMAN ANCH`* port.
#   >
#   > + 40.3k _tonnes_ of Oil or chemicals was exported from *`TUAPSE ANCH`* port.
#   >
#   > + 37.6k _tonnes_ of Oil or chemicals was exported from *`Taman'`* port.
#   >
#   > + 37.3k _tonnes_ of Oil or chemicals was exported from *`Tuapse`* port.
#   >
#   > + 52.0k _tonnes_ of Crude oil, 351.0k tonnes of Oil or chemicals and 202.5k tonnes of Oil products were exported from *`Ust'-Lugak`* port.
#   >
#   > + 126.9k _tonnes_ of Oil or chemicals was exported from *`Vysotsk`* port.

# %% [markdown]
# <a id='rq11'></a>
# ### How many tonnes of products arrived the three ports?
# ![Tonnes_of_Commodities_Arrived_Port.png](attachment:Tonnes_of_Commodities_Arrived_Port.png)
#
# ### Narrative
# > There are *`3`* unique/distinct arrival_port_name available in the dataset.
# >
# > **Scenario 1** - Before invasion
#   > + 296.1k _tonnes_ of products arrived `LAGOS ANCH` port.
#   >
#   > + 129.9k _tonnes_ of products arrived `Lagos` port.
#   >
#   > + 94.4k _tonnes_ of products arrived `Port Harcourt`.
# >
# > **Scenario 2** - Since invasion
#   > + 655.1k _tonnes_ of products arrived `LAGOS ANCH` port.
#   >
#   > + 182.4k _tonnes_ of products arrived `Lagos` port.
#   >
#   > + 40.2k _tonnes_ of Oil or chemicals arrived `Port Harcourt`.

# %% [markdown]
# <a id='rq12'></a>
# ### How many tonnes of commodities arrived the three ports? A more detailed outlook
# ![Tonnes_of_Commodities_Arrived_Port_Detailed.png](attachment:Tonnes_of_Commodities_Arrived_Port_Detailed.png)
#
# ### Narrative
# > There are *`3`* unique/distinct arrival_port_name available in the dataset.
# >
# > **Scenario 1** - Before invasion
#   > + 101.9k _tonnes_ of Oil or chemicals, 194.2k tonnes of Oil products arrived `LAGOS ANCH` port.
#   >
#   > + 129.9k _tonnes_ of Oil or chemicals arrived `Lagos` port.
#   >
#   > + 94.4k _tonnes_ of Oil products arrived `Port Harcourt`.
# >
# > **Scenario 2** - Since invasion
#   > + 354.8k _tonnes_ of Oil or chemicals, 248.3k tonnes of Oil products and 52k tonnes of Crude oil arrived `LAGOS ANCH` port.
#   >
#   > + 137.5k _tonnes_ of Oil or chemicals, 44.8k tonnes of Coal arrived `Lagos` port.
#   >
#   > + 40.2k _tonnes_ of Oil or chemicals arrived `Port Harcourt`.

# %% [markdown]
# <a id='rq13'></a>
# ### Who are the managers of the vessels?
# ![Managers_of_Vessels.png](attachment:Managers_of_Vessels.png)
#
# ### Narrative
# > There are *`19`* unique/distinct ship_manager available in the dataset.
# >
# > **Scenario 1** - Before and since invasion
#   > + *PRODUCT SHIPPING & TRADING SA managed* vessels `seven times` before invasion and `two times` since invasion.
# >
# > **Scenario 2** - Before invasion only
#   > + *DONNELLY TANKER MANAGEMENT-MAI* managed vessels twice. *GENEL DENIZCILIK NAKLIYATI AS* and *ATLANTAS SHIP MANAGEMENT LTD* managed vessels `once for each one`.
#   >
# >
# > **Scenario 3** - Since invasion only
#   > + *ALBERTA SHIPMANAGEMENT LTD* and *EASTERN MEDITERRANEAN MTME-LIE* managed vessels `two and three times` respectively.
#   >
#   > + *PETRA SHIPMANAGEMENT LTD, TSAKOS SHIPPING & TRADING SA, CYMARE SHIPMANAGEMENT LTD, COLUMBIA SHIPMANAGEMENT-GEU, THENAMARIS SHIPS MANAGEMENT, MINERVA MARINE INC, SEA WORLD MANAGEMENT & TRADING, BERNHARD SCHULTE SHIPPING, OCEANGOLD TANKERS INC, EXECUTIVE SHIP MANAGEMENT, MCF SHIPPING DMCC* and *BESIKTAS LIKID TASIMACILIK* managed vessels `once for each one`.
#   >
#   > + *UNKNOWN* managed three vessels.
# >
# > Note that the owner of *`ARCTIC CHAR`* and *`ANCE`* vessels are missing or unvailable. The missing managers are seen `before invasion`.

# %% [markdown]
# <a id='rq14'></a>
# ### Which country do the ship managers come from?
# ![Countries_of_ShipManagers.png](attachment:Countries_of_ShipManagers.png)
#
# ### Narrative
# > There are *`18`* unique ship managers. The dataset contains one unknown/missing ship manager.
# >
# > + 10 of the managers are from `Greece`.
# >
# > + `Singapore` and `Turkey` have 2 managers each.
# >
# > + `Cyprus`, `Germany`, `United Arab Emirates`, `United Kingdom` have one manager each.

# %% [markdown]
# <a id='rq15'></a>
# ### Who are the owners of the vessels?
# ![Owners_of_Vessels.png](attachment:Owners_of_Vessels.png)
#
# ### Narrative
# > There are *`26`* unique/distinct ship_owner available in the dataset.
# >
# > **Scenario 1** - Before Invasion
#   > + the vessels owned by _VISTA SHIPHOLDING IV PTE LTD_ and _PST ENERGY 4 SHIPPING LLC_ were used `two` and `six times` respectively.
#   >
#   > + the vessels owned by _MALINDI NAVIGATION LTD, RIVER POINT LLC_ and _BALMORAL PARTNERS LTD_ were used `once for each one`.
# >
# > **Scenario 2** - Since Invasion
# >
# > + the vessel owned by _DOBBY SHIPPING LTD_ was used `2 times`.
# >
# > + the remaining vessels owned by _HANA SHIPPING & MARINE INC, EL GAIA SHIPPING INC, VICTORY FAITH SA, GRACE LUCRUM SHIPPING LTD, HIGH SEAS SHIPPING LLC, STEELTANK MARITIME LTD, ISTION VENTURES CORP, EVENSTAR SHIPPING INC, LADIES SHIPPING LTD, PLUS SHIPMANAGEMENT CORP, MANDARIN SHIPPING LTD, APHRODITE SHIPOWNING INC, NIRVANA PRODUCT TRADING INC, BARONE SHIPPING LTD, CL NANHU LTD, GREATER BLOOM LTD, FAIR WEATHER SHIPPING LTD, WASP NAVIGATION CO, ESENTEPE SHIPPING LTD_ and _SCOPS NAVIGATION SA_ were used `once for each one`.
# >
# > Note that the owner of *`ARCTIC CHAR`* and *`ANCE`* vessels are missing or unvailable. The missing owners are seen before invasion.

# %% [markdown]
# <a id='rq16'></a>
# ### Which country do the ship owners come from?
# ![Countries_of_shipOwners2.png](attachment:Countries_of_shipOwners2.png)
#
# ### Narrative
# > There are *`26`* unique ship_owner.
# >
# > + 14 of the ship owners are from `Greece`.
# >
# > + 4 of the ship owners are from `United Arab Emirates`.
# >
# > + `Singapore` and `Denmark` have two ship owners each.
# >
# > + `Cyprus`, `United Kingdow` and `Turkey` have one ship owner each.

# %% [markdown]
# <a id='rq17'></a>
# ### Insurance companies before and since invasion
# ![Insurance_Companies_of_the_Vessels.png](attachment:Insurance_Companies_of_the_Vessels.png)
#
# ### Narrative
# > There are *`9`* unique ship_insurer plus an *`unknown`* ship_insurer.
# >
# >+ *American Steamship Owner P&I association, Britannia Steamship insurance Association Ld* and *UK P&I Club* are seen `before
# and since invasion`.
# >
# >+ *Assuranceforeningen Gard - Norway* and *The West of England Shipowners* are the ship insurers `before the invasion only`.
# >
# >+ *North of England P&I Association, Standard P&I Club per Charles Taylor & Co, Steamship Mutual Underwriting Association (Bermuda)* and *Sveriges Angfartys Assurans Forening (Swedish Club)* are the ship insurers `since invasion only`

# %% [markdown]
# <a id='rq2'></a>
# ### Where are those ships insured?
# ![Ships_and_their_insurance_companies.png](attachment:Ships_and_their_insurance_companies.png)
#
# ### Narrative
# > There are *`9`* unique ship_insurer plus an *`unknown`* ship_insurer.
# >
# >+ *American Steamship Owner P&I association* is the insurer of *`ANCE`* and *`LOUIE`* ships.
# >
# >+ *UK P&I Club* is the insurer of *`DUMBLEDORE,  ANDROMEDA, CLEAN NIRVANA`* and *`HAFNIA BEIJING`* ships.
# >
# >+ *Sveriges Angfartys Assurans Forening (Swedish Club)* is the insurer of *`FALCON NOSTOS`* and *`MARLIN AMMOLITE`* ships.
# >
# >+ *Britannia Steamship insurance Association Ld* is the insurer of *`DYLAN, LUCKY LADY,  CLEAROCEAN MIRACLE, LORELEI`* and *`NORTHERN LIGHT`* ships.
# >
# >+ *Standard P&I Club per Charles Taylor & Co* is the insurer of *`CAPE GAVI, ST NICHOLAS, LUCKY SAILOR`* and *`AGIOS NIKOLAOS IV`* ships.
# >
# >+ *North of England P&I Association* is the insurer of *`ALPINE LIGHT`* and *`MINERVA PACIFICA`* ships.
# >
# >+ *Assuranceforeningen Gard - Norway* is the insurer of *`ARCTIC CHAR`* ship.
# >
# >+ *The West of England Shipowners* is the insurer of *`BONDI`* and *`ADVANTAGE POINT`* ships.
# >
# >+ *Steamship Mutual Underwriting Association (Bermuda)* is the insurer of *`ESENTEPE`* ship.
# >
# > However, *`NAVE DORADO, JANE, TATIANA P,  NS STREAM`* and *`SCF ANGARA`* ships have an *unknown* ship insurer.

# %% [markdown]
# <a id='rq18'></a>
# ### Which countries are the insurance companies located?
# ![Location_of_Insurance_Companies.png](attachment:Location_of_Insurance_Companies.png)
#
# ### Narrative
# > There are *`5`* distinct ship insurer countries and one *Unavailable*.
# >
# > + *Britannia Steamship insurance Association Ld, North of England P&I Association, Standard P&I Club per Charles Taylor & Co,
# The West of England Shipowners* and *UK P&I Club* are from `United Kingdom`.
# >
# > + *American Steamship Owner P&I association* is from the `United States`.
# >
# > + *Sveriges Angfartys Assurans Forening (Swedish Club)* from `Sweden`.
# >
# > + *Assuranceforeningen Gard - Norway* from `Norway`.
# >
# > + *Steamship Mutual Underwriting Association (Bermuda)* from `Bermuda`.
